# %% [markdown]
# # TensorFlow卷积神经网络(CNN)示例 - 原生API
# ### Convolutional Neural Network Example - Raw API

# %% [markdown]
# ## CNN网络结构图示
#
# ![CNN](http://personal.ie.cuhk.edu.hk/~ccloy/project_target_code/images/fig3.png)
#
# ## MNIST数据集
#
#
# ![MNIST Dataset](http://neuralnetworksanddeeplearning.com/images/mnist_100_digits.png)
#
# More info: http://yann.lecun.com/exdb/mnist/

# %%
from __future__ import division, print_function, absolute_import

import tensorflow as tf

# Import MNIST data，MNIST数据集导入
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("../MNIST_data/", one_hot=True)
# Out:
# WARNING:tensorflow:From /anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting ../MNIST_data/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From /anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting ../MNIST_data/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Extracting ../MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting ../MNIST_data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %%
# Hyper-parameters，超参数
learning_rate = 0.001
num_steps = 1000
batch_size = 128
display_step = 10

# Network Parameters，网络参数
num_input = 784 # MNIST数据输入 (img shape: 28*28)
num_classes = 10 # MNIST所有类别 (0-9 digits)
dropout = 0.75 # Dropout, probability to keep units = (1-p)，保留神经元相应的概率为(1-p)=(1-0.75)=0.25

# tf Graph input，TensorFlow图结构输入
X = tf.placeholder(tf.float32, [None, num_input])
Y = tf.placeholder(tf.float32, [None, num_classes])
keep_prob = tf.placeholder(tf.float32) # dropout (keep probability)，保留i

# %%
# Create some wrappers for simplicity，创建基础卷积函数，简化写法
def conv2d(x, W, b, strides=1):
    # Conv2D wrapper, with bias and relu activation，卷积层，包含bias与非线性relu激励
    x = tf.nn.conv2d(x, W, strides=[1, strides, strides, 1], padding='SAME')
    x = tf.nn.bias_add(x, b)
    return tf.nn.relu(x)


def maxpool2d(x, k=2):
    # MaxPool2D wrapper，最大池化层
    return tf.nn.max_pool(x, ksize=[1, k, k, 1], strides=[1, k, k, 1],
                          padding='SAME')


# Create model，创建模型
def conv_net(x, weights, biases, dropout):
    # MNIST数据为维度为1，长度为784 (28*28 像素)的
    # Reshape to match picture format [Height x Width x Channel]
    # Tensor input become 4-D: [Batch Size, Height, Width, Channel]
    x = tf.reshape(x, shape=[-1, 28, 28, 1])

    # Convolution Layer，卷积层
    conv1 = conv2d(x, weights['wc1'], biases['bc1'])
    # Max Pooling (down-sampling)，最大池化层／下采样
    conv1 = maxpool2d(conv1, k=2)

    # Convolution Layer，卷积层
    conv2 = conv2d(conv1, weights['wc2'], biases['bc2'])
    # Max Pooling (down-sampling)，最大池化层／下采样
    conv2 = maxpool2d(conv2, k=2)

    # Fully connected layer，全连接网络
    # Reshape conv2 output to fit fully connected layer input，调整conv2层输出的结果以符合全连接层的需求
    fc1 = tf.reshape(conv2, [-1, weights['wd1'].get_shape().as_list()[0]])
    fc1 = tf.add(tf.matmul(fc1, weights['wd1']), biases['bd1'])
    fc1 = tf.nn.relu(fc1)
    # Apply Dropout，应用dropout
    fc1 = tf.nn.dropout(fc1, dropout)

    # Output, class prediction，最后输出预测
    out = tf.add(tf.matmul(fc1, weights['out']), biases['out'])
    return out

# %%
# Store layers weight & bias 存储每一层的权值和全差
weights = {
    # 5x5 conv, 1 input, 32 outputs
    'wc1': tf.Variable(tf.random_normal([5, 5, 1, 32])),
    # 5x5 conv, 32 inputs, 64 outputs
    'wc2': tf.Variable(tf.random_normal([5, 5, 32, 64])),
    # fully connected, 7*7*64 inputs, 1024 outputs
    'wd1': tf.Variable(tf.random_normal([7*7*64, 1024])),
    # 1024 inputs, 10 outputs (class prediction)
    'out': tf.Variable(tf.random_normal([1024, num_classes]))
}

biases = {
    'bc1': tf.Variable(tf.random_normal([32])),
    'bc2': tf.Variable(tf.random_normal([64])),
    'bd1': tf.Variable(tf.random_normal([1024])),
    'out': tf.Variable(tf.random_normal([num_classes]))
}

# Construct model，构建模型
logits = conv_net(X, weights, biases, keep_prob)
prediction = tf.nn.softmax(logits)

# Define loss and optimizer，定义误差函数与优化器
loss_op = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(
    logits=logits, labels=Y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
train_op = optimizer.minimize(loss_op)


# Evaluate model，评估模型
correct_pred = tf.equal(tf.argmax(prediction, 1), tf.argmax(Y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initialize the variables (i.e. assign their default value)，初始化图结构所有变量
init = tf.global_variables_initializer()
# Out:
# WARNING:tensorflow:From <ipython-input-5-c59ecf8fadf0>:26: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.

# %%
# Start training，开始训练
with tf.Session() as sess:

    # Run the initializer，初始化
    sess.run(init)

    for step in range(1, num_steps+1):
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        # Run optimization op (backprop)，优化
        sess.run(train_op, feed_dict={X: batch_x, Y: batch_y, keep_prob: dropout})
        if step % display_step == 0 or step == 1:
            # Calculate batch loss and accuracy
            loss, acc = sess.run([loss_op, accuracy], feed_dict={X: batch_x,
                                                                 Y: batch_y,
                                                                 keep_prob: 1.0})
            print("Step " + str(step) + ", Minibatch Loss= " + \
                  "{:.4f}".format(loss) + ", Training Accuracy= " + \
                  "{:.3f}".format(acc))

    print("Optimization Finished!")

    # Calculate accuracy for 256 MNIST test images，以每256个测试图像为例，
    print("Testing Accuracy:", \
        sess.run(accuracy, feed_dict={X: mnist.test.images[:256],
                                      Y: mnist.test.labels[:256],
                                      keep_prob: 1.0}))
# Out:
# Step 1, Minibatch Loss= 55960.4766, Training Accuracy= 0.141
# Step 10, Minibatch Loss= 25866.4062, Training Accuracy= 0.211
# Step 20, Minibatch Loss= 16163.4951, Training Accuracy= 0.422
# Step 30, Minibatch Loss= 5988.7832, Training Accuracy= 0.648
# Step 40, Minibatch Loss= 4057.0288, Training Accuracy= 0.758
# Step 50, Minibatch Loss= 3102.5078, Training Accuracy= 0.805
# Step 60, Minibatch Loss= 3245.6479, Training Accuracy= 0.789
# Step 70, Minibatch Loss= 2659.2886, Training Accuracy= 0.883
# Step 80, Minibatch Loss= 2257.2236, Training Accuracy= 0.859
# Step 90, Minibatch Loss= 2416.6709, Training Accuracy= 0.875
# Step 100, Minibatch Loss= 1916.1954, Training Accuracy= 0.852
# Step 110, Minibatch Loss= 1819.2759, Training Accuracy= 0.852
# Step 120, Minibatch Loss= 1968.9437, Training Accuracy= 0.898
# Step 130, Minibatch Loss= 2437.6738, Training Accuracy= 0.898
# Step 140, Minibatch Loss= 1339.0239, Training Accuracy= 0.930
# Step 150, Minibatch Loss= 1493.3505, Training Accuracy= 0.891
# Step 160, Minibatch Loss= 811.7616, Training Accuracy= 0.938
# Step 170, Minibatch Loss= 1485.6213, Training Accuracy= 0.898
# Step 180, Minibatch Loss= 1069.2791, Training Accuracy= 0.930
# Step 190, Minibatch Loss= 1290.8147, Training Accuracy= 0.930
# Step 200, Minibatch Loss= 1687.4285, Training Accuracy= 0.906
# Step 210, Minibatch Loss= 1590.7676, Training Accuracy= 0.906
# Step 220, Minibatch Loss= 535.2298, Training Accuracy= 0.938
# Step 230, Minibatch Loss= 1557.5698, Training Accuracy= 0.898
# Step 240, Minibatch Loss= 747.1925, Training Accuracy= 0.938
# Step 250, Minibatch Loss= 1737.8281, Training Accuracy= 0.914
# Step 260, Minibatch Loss= 325.4633, Training Accuracy= 0.953
# Step 270, Minibatch Loss= 635.3698, Training Accuracy= 0.945
# Step 280, Minibatch Loss= 778.7346, Training Accuracy= 0.938
# Step 290, Minibatch Loss= 1165.8472, Training Accuracy= 0.922
# Step 300, Minibatch Loss= 659.3618, Training Accuracy= 0.945
# Step 310, Minibatch Loss= 1258.9482, Training Accuracy= 0.898
# Step 320, Minibatch Loss= 1015.0795, Training Accuracy= 0.938
# Step 330, Minibatch Loss= 684.2562, Training Accuracy= 0.938
# Step 340, Minibatch Loss= 541.8737, Training Accuracy= 0.930
# Step 350, Minibatch Loss= 1292.3519, Training Accuracy= 0.914
# Step 360, Minibatch Loss= 889.7889, Training Accuracy= 0.945
# Step 370, Minibatch Loss= 990.3300, Training Accuracy= 0.930
# Step 380, Minibatch Loss= 726.2776, Training Accuracy= 0.914
# Step 390, Minibatch Loss= 685.4808, Training Accuracy= 0.953
# Step 400, Minibatch Loss= 294.7143, Training Accuracy= 0.961
# Step 410, Minibatch Loss= 1023.0895, Training Accuracy= 0.930
# Step 420, Minibatch Loss= 735.2111, Training Accuracy= 0.914
# Step 430, Minibatch Loss= 393.4777, Training Accuracy= 0.953
# Step 440, Minibatch Loss= 608.2361, Training Accuracy= 0.930
# Step 450, Minibatch Loss= 273.3395, Training Accuracy= 0.953
# Step 460, Minibatch Loss= 753.6863, Training Accuracy= 0.938
# Step 470, Minibatch Loss= 730.4313, Training Accuracy= 0.930
# Step 480, Minibatch Loss= 605.8164, Training Accuracy= 0.945
# Step 490, Minibatch Loss= 150.9915, Training Accuracy= 0.969
# Step 500, Minibatch Loss= 571.8423, Training Accuracy= 0.945
# Step 510, Minibatch Loss= 70.7875, Training Accuracy= 0.977
# Step 520, Minibatch Loss= 322.6788, Training Accuracy= 0.953
# Step 530, Minibatch Loss= 426.3432, Training Accuracy= 0.969
# Step 540, Minibatch Loss= 656.2122, Training Accuracy= 0.938
# Step 550, Minibatch Loss= 793.6537, Training Accuracy= 0.945
# Step 560, Minibatch Loss= 166.2398, Training Accuracy= 0.977
# Step 570, Minibatch Loss= 336.0071, Training Accuracy= 0.953
# Step 580, Minibatch Loss= 370.0952, Training Accuracy= 0.961
# Step 590, Minibatch Loss= 682.2931, Training Accuracy= 0.945
# Step 600, Minibatch Loss= 403.4044, Training Accuracy= 0.945
# Step 610, Minibatch Loss= 64.5405, Training Accuracy= 0.984
# Step 620, Minibatch Loss= 337.4465, Training Accuracy= 0.969
# Step 630, Minibatch Loss= 189.2766, Training Accuracy= 0.969
# Step 640, Minibatch Loss= 462.6129, Training Accuracy= 0.945
# Step 650, Minibatch Loss= 670.1334, Training Accuracy= 0.969
# Step 660, Minibatch Loss= 481.8845, Training Accuracy= 0.945
# Step 670, Minibatch Loss= 230.4830, Training Accuracy= 0.969
# Step 680, Minibatch Loss= 152.0978, Training Accuracy= 0.969
# Step 690, Minibatch Loss= 283.9657, Training Accuracy= 0.961
# Step 700, Minibatch Loss= 142.2230, Training Accuracy= 0.992
# Step 710, Minibatch Loss= 808.4225, Training Accuracy= 0.953
# Step 720, Minibatch Loss= 217.5199, Training Accuracy= 0.961
# Step 730, Minibatch Loss= 95.9029, Training Accuracy= 0.977
# Step 740, Minibatch Loss= 227.3191, Training Accuracy= 0.969
# Step 750, Minibatch Loss= 400.2076, Training Accuracy= 0.961
# Step 760, Minibatch Loss= 994.5928, Training Accuracy= 0.930
# Step 770, Minibatch Loss= 419.8887, Training Accuracy= 0.961
# Step 780, Minibatch Loss= 340.8039, Training Accuracy= 0.938
# Step 790, Minibatch Loss= 529.0147, Training Accuracy= 0.953
# Step 800, Minibatch Loss= 226.1148, Training Accuracy= 0.969
# Step 810, Minibatch Loss= 323.7549, Training Accuracy= 0.953
# Step 820, Minibatch Loss= 401.7019, Training Accuracy= 0.969
# Step 830, Minibatch Loss= 809.4675, Training Accuracy= 0.969
# Step 840, Minibatch Loss= 294.6503, Training Accuracy= 0.969
# Step 850, Minibatch Loss= 629.2668, Training Accuracy= 0.938
# Step 860, Minibatch Loss= 498.3544, Training Accuracy= 0.945
# Step 870, Minibatch Loss= 75.7011, Training Accuracy= 0.984
# Step 880, Minibatch Loss= 126.1228, Training Accuracy= 0.969
# Step 890, Minibatch Loss= 132.3893, Training Accuracy= 0.977
# Step 900, Minibatch Loss= 195.2244, Training Accuracy= 0.977
# Step 910, Minibatch Loss= 76.4815, Training Accuracy= 0.969
# Step 920, Minibatch Loss= 687.4004, Training Accuracy= 0.945
# Step 930, Minibatch Loss= 574.8568, Training Accuracy= 0.961
# Step 940, Minibatch Loss= 55.9399, Training Accuracy= 0.992
# Step 950, Minibatch Loss= 184.1278, Training Accuracy= 0.977
# Step 960, Minibatch Loss= 354.6603, Training Accuracy= 0.961
# Step 970, Minibatch Loss= 123.0681, Training Accuracy= 0.969
# Step 980, Minibatch Loss= 288.0328, Training Accuracy= 0.977
# Step 990, Minibatch Loss= 487.0388, Training Accuracy= 0.953
# Step 1000, Minibatch Loss= 62.2660, Training Accuracy= 0.984
# Optimization Finished!
# Testing Accuracy: 0.98828125
